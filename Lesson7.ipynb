# %% [markdown]
# Lesson 7-1
# ==
# Временные ряды и графики дат.
# ---

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dates = pd.date_range('20240101', periods=6)
values = [1, 3, 2, 5, 0, 4]

plt.plot(dates, values)
plt.show()

# %% [markdown]
# Цветовые карты.
# --

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('intensity')
plt.show()

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.hexbin(x, y, gridsize=1000, cmap='Blues')
cb = plt.colorbar()
cb.set_label('intensity')
plt.show()

# %% [markdown]
# Тепловые карты.
# ---

# %%
data = np.random.rand(10, 10)
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
data[0,3]
# Out:
# 0.05444915583990795

# %%
#data = np.random.rand(10, 10)
plt.imshow(data, cmap='hot', interpolation='nearest', alpha = .1)
for x in range(10):
    for y in range(10):
        plt.text(x-0.1 , y-0.1 ,'%.1f' % data[x, y])
plt.colorbar()
plt.show()

# %% [markdown]
# Задание для закрепления.
# --
# В двумерном списке дана дневная и ночная температура в Берлине в январе 2024 года:
# [[8, 5, 11, 4, 1, 0, -1, -6, -6, -4, -2, 0, 3, 3, 2, 1, 0, 0, 1, 2, 2, 9, 7, 11, 8, 9, 6, 6, 8, 8, 6],
#  [6, 6, 9, 1, 0, 1, -2, -8, -8, -7, 0, 1, 3, 3, 1, -1,  -2, -1, -3, 0, -3, 2, 6, 6, 8, 4, 5, 2, 1, 3, 8]]
# Постройте тепловую карту по этим данным.

# %%
temp = [[8, 5, 11, 4, 1, 0, -1, -6, -6, -4, -2, 0, 3, 3, 2,
         1, 0, 0, 1, 2, 2, 9, 7, 11, 8, 9, 6, 6, 8, 8, 6], 
        [6, 6, 9, 1, 0, 1, -2, -8, -8, -7, 0, 1, 3, 3, 1, -1,
         -2, -1, -3, 0, -3, 2, 6, 6, 8, 4, 5, 2, 1, 3, 8]]
plt.imshow(temp, cmap='spring')
plt.yticks([0, 1], ["день", "ночь"])
plt.colorbar(location="bottom")
plt.show()

# %% [markdown]
# Работа с несколькими фигурами и осями
# --

# %%
# Линейная зависимость
x = np.linspace(0, 10, 50)
y1 = x
# Квадратичная зависимость
y2 = [i**2 for i in x]
# Построение графиков
plt.figure(figsize=(9, 9))
plt.subplot(2, 1, 1)
plt.plot(x, y1)               # построение графика
plt.title(r"Зависимость $y_1 = x$") # заголовок
plt.ylabel(r"$y_1$", fontsize=14) # ось ординат
plt.grid(True)                # включение отображение сетки
plt.subplot(2, 1, 2)
plt.plot(x, y2)               # построение графика
plt.title(r"Зависимость $y_2 = x^2$") # заголовок
plt.xlabel("x", fontsize=14)  # ось абсцисс
plt.ylabel(r"$y_2$", fontsize=14) # ось ординат
plt.grid(True)                # включение отображение сетки
plt.show()

# %% [markdown]
# Два подграфика одного рисунка могут также иметь общую ось Х, но разные оси Y. Для создания второго подграфика в этом случае нужно использовать метод twinx().

# %%
month = ['янв','фев','март','апр','май','июнь','июль','авг','сен','окт','ноя','дек']
temp = [1.8, 1.8, 4.8, 9.0, 14.0, 18.8, 19.8, 19.6, 15.0, 10.0, 5.0, 2.0]
prec = [56, 41, 53, 42, 60, 67, 81, 62, 56, 49, 48, 54]

plt.figure()
ax1 = plt.subplot()

ax1.set_xlabel('Month')
ax1.set_ylabel(r'Temperature, $\degree$C', color='red')
ax1.plot(month, temp, color='red')
ax1.tick_params(axis='y', labelcolor='red')

ax2 = ax1.twinx()
ax2.set_ylabel('Precipitation, mm', color='blue')
ax2.plot(month, prec, color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

plt.show()

# %% [markdown]
# Еще одна возможность отобразить разную информацию на одном рисунке – использование вложенных графиков. Для этого нужно воспользоваться функцией axes(), которая создает оси в заданном прямоугольнике. При этом вся площадь рисунка описывается прямоугольником [0, 0, 1, 1].
#
# plt.axes([x, y, width, height])

# %%
# Основной график
plt.axes([0, 0, 1, 1])
plt.plot(range(10), color='red')
plt.title('Основной график')

# Вложенный график
plt.axes([0.2, 0.6, 0.25, 0.25])
plt.plot(range(10), color='blue')
plt.title('Вложенный график')
plt.show()

# %% [markdown]
# Задание для закрепления.
# С помощью функции axes() расположите графики из предыдущего примера рядом друг с другом, одинакового размера.

# %%
plt.axes([0, 0, 0.4, 1.0])
plt.plot(range(10), color='red')
plt.title('Первый график')

plt.axes([0.6, 0, 0.4, 1.0])
plt.plot(range(10), color='blue')
plt.title('Второй график')
plt.show()

# %% [markdown]
# 3D графики.
# --

# %%
from mpl_toolkits.mplot3d import Axes3D
fr

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y) #создаем матрицу из всех возможных комбинаций X и Y
Z = np.sin(np.sqrt(X**2 + Y**2))

surf = ax.plot_surface(X, Y, Z, cmap='viridis')
fig.colorbar(surf)
ax.can_zoom()
plt.show()

# %% [markdown]
# Контурные графики.
# ---

# %%
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))

plt.contourf(X, Y, Z, cmap='viridis')
plt.colorbar()
plt.show()

# %% [markdown]
# Визуализация географических данных.
# ---

# %%
# !pip install cartopy

# %%
#%matplotlib widget

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature


plt.figure(figsize=(10, 5))
ax = plt.axes([0, 0, 1, 1], projection=ccrs.PlateCarree())
ax.add_feature(cfeature.LAND) # отображение суши
ax.add_feature(cfeature.OCEAN) # отображение океанов
ax.add_feature(cfeature.COASTLINE) # отображение береговой линии
ax.add_feature(cfeature.BORDERS) # отображение границ стран
ax.add_feature(cfeature.LAKES, alpha=0.5) # отображение озер
ax.add_feature(cfeature.RIVERS) # отображение рек
ax.add_feature(cfeature.STATES) # отображение границ штатов США

plt.show()

# %% [markdown]
# Задачи
# --
# 1. Имеются данные о количестве осадков в Берлине по месяцам:
# prec = [56, 41, 53, 42, 60, 67, 81, 62, 56, 49, 48, 54]
#
# По этим данным постройте 4 диаграммы: точечный график, гистограмму (4 бина), круговую и столбчатую диаграммы. Графики должны быть расположены в два ряда и два столбца.

# %%
# %matplotlib inline

# %%
prec = [56, 41, 53, 42, 60, 67, 81, 62, 56, 49, 48, 54]
month = range(1,13)
plt.figure(figsize=(9, 9))
plt.subplot(2,2,1)
plt.plot(month, prec)
plt.title("График количества осадков") 
plt.ylabel("Количество осадков") 
plt.grid(True)  


plt.subplot(2,2,2)
plt.hist(prec, bins = 4)
plt.title("Гистограмма распределения осадков") 
plt.ylabel("Количество месяцев")


plt.subplot(2,2,3)
plt.pie(prec, labels = month, autopct='%1.1f%%', textprops={'fontsize': 8})
plt.title("Круговая диаграмма")


plt.subplot(2,2,4)
plt.bar(x=month, height=prec)
plt.title("Столбчатая диаграмма") 
plt.ylabel("Количество осадков") 

plt.show()

# %% [markdown]
# 2. На одной системе координат постройте два трехмерных графика: Z=X*Y и Z=-X*Y.

# %%
#%matplotlib widget
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
Z = -X*Y
surf = ax.plot_surface(X, Y, Z, cmap='Oranges')
Z = X*Y
surf = ax.plot_surface(X, Y, Z, cmap='viridis')
ax.can_zoom()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Lesson 7-2
# ==
# Визуализация данных, встроенная в pandas
# --

# %%
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=['A', 'B', 'C', 'D'])

# %%
plt.clf() # clear previous figure

# %%
df['A'].plot(kind='hist')
plt.show()

# %%
# настройка параметров
df.plot(kind='scatter', x='A', y='B', color='red', label='Group 1')
plt.title('Scatter Plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
# использование группировки
df = pd.DataFrame({'A': np.random.randint(1, 5, 10),
                   'B': np.random.rand(10)})
df.groupby('A').sum().plot(kind='bar')
plt.show()

# %% [markdown]
# Задание на закрепление.
# Для датафрейма из предыдущего примера постройте круговую диаграмму для средних значений при группировке по значениям столбца А.

# %%
df.groupby('A').mean()
# Out:
#           B
# A
# 1  0.449349
# 2  0.281245
# 3  0.879168
# 4  0.560757

# %%
#df.groupby('A').mean().plot(kind='pie')
# не сработает, потому что мы хотим сделать круговую диаграмму на весь датафрейм

# %%
#сработает из-за subplots
df.groupby('A').mean().plot(kind='pie', subplots=True)
# Out:
# array([<Axes: ylabel='B'>], dtype=object)

# %%
df.groupby('A').mean().plot(kind='pie', y = 'B') # сработает, потому что указали колонку
# Out:
# <Axes: ylabel='B'>

# %%
# сработает, потому что это серия
df.groupby('A')['B'].mean().plot(kind='pie')
# Out:
# <Axes: ylabel='B'>

# %%
df = pd.DataFrame({'A': np.random.randint(1, 5, 10),
                   'B': np.random.rand(10),
                  'C':  np.random.rand(10)})

df.groupby('A').mean().plot(kind='pie', subplots=True,autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='B'>, <Axes: ylabel='C'>], dtype=object)

# %%
df.groupby('A').mean().plot(kind='bar') #bar работает потому, что мы можем иметь несколько графиком на одном холсте
# Out:
# <Axes: xlabel='A'>

# %% [markdown]
# Создание сложных макетов.
# --

# %%
fig, axes = plt.subplots(figsize=(9, 9), nrows=2, ncols=1) # эта функция объединяет plt.figure() и plt.subplot()
df['A'].plot(ax=axes[0], kind='line', title='Line Plot')
df['B'].plot(ax=axes[1], kind='bar', title='Bar Plot')
plt.show()

# %% [markdown]
# Стековые графики.
# --

# %%
df.plot(kind='area')
plt.title('Stacked Area Plot')
plt.show()

# %% [markdown]
# Задание для закрепления.
# У вас есть три бизнес-метрики за первую половину 2023 года:
# 'sales': [3, 2, 3, 9, 10, 6],
#  'signups': [5, 5, 6, 12, 14, 13],
#  'visits': [20, 42, 28, 62, 81, 50]
# Создайте дата-фрейм с этими метриками, индексами в котором будут указанные месяцы. Постройте стековый график.

# %%
df = pd.DataFrame({
                         'sales': [3, 2, 3, 9, 10, 6], 'signups': [5, 5, 6, 12, 14, 13], 'visits': [20, 42, 28, 62, 81, 50] },
                 index = range(1,7))

# %%
df.plot(kind = 'area')
# Out:
# <Axes: >

# %% [markdown]
# Графики с разбивкой по категориям.
# --

# %%
df = pd.DataFrame({'A': np.random.randint(1, 5, 10),
                   'B': np.random.rand(10),
                  'C': np.random.choice(['Category 1', 'Category 2'], size=10)})


df.plot(kind="hist", figsize=(9, 9), column='B', by='C')
plt.show()

# %% [markdown]
# Парные графики и матрицы рассеяния.
# --

# %%
from pandas.plotting import scatter_matrix


scatter_matrix(df_new, figsize=(10, 10))
plt.show()

# %% [markdown]
# Задание на закрепление.
# Для данных о средней температуре и количестве осадков в Берлине по месяцам
# temp = [1.8, 1.8, 4.8, 9.0, 14.0, 18.8, 19.8, 19.6, 15.0, 10.0, 5.0, 2.0]
# prec = [56, 41, 53, 42, 60, 67, 81, 62, 56, 49, 48, 54]
# создайте датафрейм и матрицу рассеяния для него.

# %%
temp = [1.8, 1.8, 4.8, 9.0, 14.0, 18.8, 19.8, 19.6, 15.0, 10.0, 5.0, 2.0]
prec = [56, 41, 53, 42, 60, 67, 81, 62, 56, 49, 48, 54]
weather=pd.DataFrame({'temp': temp, 'prec': prec})
scatter_matrix(weather, figsize=(10, 10))
plt.show()

# %% [markdown]
# Работа с датасетом Титаник
# ==
# [Ссылка на датасет](https://github.com/datasciencedojo/datasets/blob/master/titanic.csv)

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Посмотрим на распределение выживших и невыживших пассажиров среди тех, билет которых стоил менее 50 единиц.

# %%
# %matplotlib inline
df[df.Fare < 50].plot.scatter(x='Fare', y='Survived')
plt.show()

# %% [markdown]
# А теперь хотим посмотреть на то как распределены выжившие и невыжившие в зависимости от цены билета.

# %%
df.groupby('Survived').Fare.plot(kind="hist", alpha=0.5)
plt.xlim(0, 150)
plt.legend()
plt.show()

# %% [markdown]
# Ту же информацию можно визуализировать с помощью ядерной оценки плотности (kde) – это способ представления распределения данных, основанный на идее сглаживания гистограммы:

# %%
df.groupby('Survived').Fare.plot(kind="kde")
plt.xlim(0, 150)
plt.legend()
plt.show()

# %%
#Можем посмотреть распределение цены, например
ax = df.Fare.plot.hist()
ax.set_title('Visualization')
plt.show()

# %%
ax = df.Fare.hist()
ax.set_title('Visualization')
plt.show()

# %% [markdown]
# Задачи
# ---
# 1. Визуализировать распределение медианных цен на дома в датасете California Housing. Этот датасет содержит информацию о различных характеристиках жилых районов Калифорнии, собранную в 1990-х годах. В нём представлены такие данные, как среднее количество комнат в доме, медианный возраст домов, среднее количество жильцов, средняя величина их дохода и медианная стоимость домов.
#
#  pip install scikit-learn

# %%
from sklearn.datasets import fetch_california_housing

california = fetch_california_housing(as_frame=True)

df = pd.DataFrame(california.data, columns=california.feature_names)
df['MEDV'] = california.target
df['MEDV'].plot(kind='hist', bins=20, color='c')
plt.title('Распределение медианных цен на жилье')
plt.xlabel('Цена')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# 2. Изучить взаимосвязь между средним количеством комнат (AveRooms) и медианной ценой на жилье (MEDV).

# %%
df.plot(kind='scatter', x='AveRooms', y='MEDV', color='b')
plt.title('Взаимосвязь между количеством комнат и ценой')
plt.xlabel('Среднее количество комнат')
plt.ylabel('Медианная цена')
plt.show()

# %%
import pkg_resources
pkg_resources.get_distribution("ipympl").version
# Out:
# '0.9.4'

# %%
import pandas as pd
df = pd.DataFrame({'x': [1,2,3]})
df
